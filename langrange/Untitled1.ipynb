# %%
import numpy as np
import pandas as pd
import datetime

# %%
df=pd.read_excel(r'langrange.xls')
df
# Out:
#          alpha0  alpha7   Alpha-7  alpha14  alpha21  Alpha-21  alpha28  \
# YAL002W   -0.11    0.10  0.748708     0.01     0.06 -0.178572     0.04
# YAL003W   -0.14   -0.71  0.758986     0.10    -0.32 -0.394257    -0.40
# YAL004W   -0.02   -0.48  0.758986    -0.11     0.12 -0.394257    -0.03
# YAL005C   -0.05   -0.53  0.180933    -0.47    -0.06 -0.160908     0.11
# YAL007C   -0.60   -0.45 -1.031976    -0.13     0.35 -0.040204    -0.01
# YAL008W   -0.28   -0.22  0.252470    -0.06     0.22 -0.227300     0.25
# YAL009W   -0.03   -0.27 -0.175095     0.17    -0.12  0.076834    -0.27
# YAL010C   -0.05    0.13  0.929112     0.13    -0.21 -0.324872    -0.45
# YAL011W   -0.31   -0.43  0.400372    -0.30    -0.23 -0.306826    -0.13
# YAL012W    0.02   -0.33  0.326051    -0.49    -0.30 -0.401873    -0.15
# YAL013W   -0.36   -0.19 -0.432457     0.00    -0.32 -0.389771    -0.27
# YAL014C   -0.10   -0.15  0.860758    -0.01    -0.25 -0.406815    -0.16
# ...

# %%
np.shape(df)
# Out:
# (4490, 24)

# %%
temp=df['alpha105'][1]
temp
# Out:
# 0.55

# %%
oval = df['alpha63'].sum()
oval/4489
# Out:
# -0.00865226108264647

# %%
pval=df['Alpha-63'].sum()
pval/4489
# Out:
# 0.03850501563772642

# %%
numerator=0
for i in range(4489):
    numerator=numerator+((df['alpha63'][i]-oval)*(df['Alpha-63'][i]-pval))
numerator
# Out:
# -30123244.571591906

# %%
denominator=0
for i in range(4489):
    denominator=denominator+(((df['alpha63'][i]-pval)**2)*((df['Alpha-63'][i]-pval)**2))
denominator
# Out:
# 4005620118740.9927

# %%
denominator=(denominator)**0.5
denominator
# Out:
# 2001404.53650455

# %%
ans=numerator/denominator
ans
# Out:
# -15.051052409525417

# %%
ans**2
# Out:
# 226.53417863428083
